# %%
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in ./jup_notebook/lib/python3.11/site-packages (1.4.0)
# Requirement already satisfied: gym<0.20,>=0.17 in ./jup_notebook/lib/python3.11/site-packages (from stable-baselines3[extra]) (0.19.0)
# Requirement already satisfied: numpy in ./jup_notebook/lib/python3.11/site-packages (from stable-baselines3[extra]) (1.24.3)
# Requirement already satisfied: torch>=1.8.1 in ./jup_notebook/lib/python3.11/site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: cloudpickle in ./jup_notebook/lib/python3.11/site-packages (from stable-baselines3[extra]) (1.6.0)
# Requirement already satisfied: pandas in ./jup_notebook/lib/python3.11/site-packages (from stable-baselines3[extra]) (2.0.1)
# Requirement already satisfied: matplotlib in ./jup_notebook/lib/python3.11/site-packages (from stable-baselines3[extra]) (3.7.1)
# Requirement already satisfied: opencv-python in ./jup_notebook/lib/python3.11/site-packages (from stable-baselines3[extra]) (4.7.0.72)
# Requirement already satisfied: atari-py==0.2.6 in ./jup_notebook/lib/python3.11/site-packages (from stable-baselines3[extra]) (0.2.6)
# Requirement already satisfied: pillow in ./jup_notebook/lib/python3.11/site-packages (from stable-baselines3[extra]) (9.5.0)
# Requirement already satisfied: tensorboard>=2.2.0 in ./jup_notebook/lib/python3.11/site-packages (from stable-baselines3[extra]) (2.12.2)
# Requirement already satisfied: psutil in ./jup_notebook/lib/python3.11/site-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: six in ./jup_notebook/lib/python3.11/site-packages (from atari-py==0.2.6->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: absl-py>=0.4 in ./jup_notebook/lib/python3.11/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in ./jup_notebook/lib/python3.11/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./jup_notebook/lib/python3.11/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in ./jup_notebook/lib/python3.11/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in ./jup_notebook/lib/python3.11/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in ./jup_notebook/lib/python3.11/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (4.22.3)
# Requirement already satisfied: requests<3,>=2.21.0 in ./jup_notebook/lib/python3.11/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.29.0)
# Requirement already satisfied: setuptools>=41.0.0 in ./jup_notebook/lib/python3.11/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (66.1.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./jup_notebook/lib/python3.11/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in ./jup_notebook/lib/python3.11/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in ./jup_notebook/lib/python3.11/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in ./jup_notebook/lib/python3.11/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.38.4)
# Requirement already satisfied: filelock in ./jup_notebook/lib/python3.11/site-packages (from torch>=1.8.1->stable-baselines3[extra]) (3.12.0)
# Requirement already satisfied: typing-extensions in ./jup_notebook/lib/python3.11/site-packages (from torch>=1.8.1->stable-baselines3[extra]) (4.5.0)
# Requirement already satisfied: sympy in ./jup_notebook/lib/python3.11/site-packages (from torch>=1.8.1->stable-baselines3[extra]) (1.11.1)
# Requirement already satisfied: networkx in ./jup_notebook/lib/python3.11/site-packages (from torch>=1.8.1->stable-baselines3[extra]) (3.1)
# Requirement already satisfied: jinja2 in ./jup_notebook/lib/python3.11/site-packages (from torch>=1.8.1->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in ./jup_notebook/lib/python3.11/site-packages (from torch>=1.8.1->stable-baselines3[extra]) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in ./jup_notebook/lib/python3.11/site-packages (from torch>=1.8.1->stable-baselines3[extra]) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in ./jup_notebook/lib/python3.11/site-packages (from torch>=1.8.1->stable-baselines3[extra]) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in ./jup_notebook/lib/python3.11/site-packages (from torch>=1.8.1->stable-baselines3[extra]) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in ./jup_notebook/lib/python3.11/site-packages (from torch>=1.8.1->stable-baselines3[extra]) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in ./jup_notebook/lib/python3.11/site-packages (from torch>=1.8.1->stable-baselines3[extra]) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in ./jup_notebook/lib/python3.11/site-packages (from torch>=1.8.1->stable-baselines3[extra]) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in ./jup_notebook/lib/python3.11/site-packages (from torch>=1.8.1->stable-baselines3[extra]) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in ./jup_notebook/lib/python3.11/site-packages (from torch>=1.8.1->stable-baselines3[extra]) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in ./jup_notebook/lib/python3.11/site-packages (from torch>=1.8.1->stable-baselines3[extra]) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in ./jup_notebook/lib/python3.11/site-packages (from torch>=1.8.1->stable-baselines3[extra]) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in ./jup_notebook/lib/python3.11/site-packages (from torch>=1.8.1->stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: cmake in ./jup_notebook/lib/python3.11/site-packages (from triton==2.0.0->torch>=1.8.1->stable-baselines3[extra]) (3.26.3)
# Requirement already satisfied: lit in ./jup_notebook/lib/python3.11/site-packages (from triton==2.0.0->torch>=1.8.1->stable-baselines3[extra]) (16.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./jup_notebook/lib/python3.11/site-packages (from matplotlib->stable-baselines3[extra]) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in ./jup_notebook/lib/python3.11/site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./jup_notebook/lib/python3.11/site-packages (from matplotlib->stable-baselines3[extra]) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./jup_notebook/lib/python3.11/site-packages (from matplotlib->stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in ./jup_notebook/lib/python3.11/site-packages (from matplotlib->stable-baselines3[extra]) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./jup_notebook/lib/python3.11/site-packages (from matplotlib->stable-baselines3[extra]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in ./jup_notebook/lib/python3.11/site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./jup_notebook/lib/python3.11/site-packages (from pandas->stable-baselines3[extra]) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./jup_notebook/lib/python3.11/site-packages (from pandas->stable-baselines3[extra]) (2023.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./jup_notebook/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./jup_notebook/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./jup_notebook/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./jup_notebook/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.2.0->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./jup_notebook/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./jup_notebook/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./jup_notebook/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in ./jup_notebook/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./jup_notebook/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard>=2.2.0->stable-baselines3[extra]) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in ./jup_notebook/lib/python3.11/site-packages (from sympy->torch>=1.8.1->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./jup_notebook/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in ./jup_notebook/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.2.0->stable-baselines3[extra]) (3.2.2)

# %%
# !pip3 install gymnasium
# Out:
# Collecting gymnasium
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 8.8 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Requirement already satisfied: numpy>=1.21.0 in ./jup_notebook/lib/python3.11/site-packages (from gymnasium) (1.24.3)
# Collecting jax-jumpy>=1.0.0
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in ./jup_notebook/lib/python3.11/site-packages (from gymnasium) (1.6.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in ./jup_notebook/lib/python3.11/site-packages (from gymnasium) (4.5.0)
# Collecting farama-notifications>=0.0.1
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, jax-jumpy, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-0.28.1 jax-jumpy-1.0.0

# %%
# !pip3 install Box2D
# Out:
# Collecting Box2D
#   Downloading Box2D-2.3.2.tar.gz (427 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.9/427.9 kB 11.1 MB/s eta 0:00:00 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: Box2D
#   Building wheel for Box2D (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [16 lines of output]
#       Using setuptools (version 66.1.1).
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.linux-x86_64-cpython-311
#       creating build/lib.linux-x86_64-cpython-311/Box2D
#       copying library/Box2D/Box2D.py -> build/lib.linux-x86_64-cpython-311/Box2D
#       copying library/Box2D/__init__.py -> build/lib.linux-x86_64-cpython-311/Box2D
#       creating build/lib.linux-x86_64-cpython-311/Box2D/b2
#       copying library/Box2D/b2/__init__.py -> build/lib.linux-x86_64-cpython-311/Box2D/b2
#       running build_ext
#       building 'Box2D._Box2D' extension
#       swigging Box2D/Box2D.i to Box2D/Box2D_wrap.cpp
#       swig -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library/Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D/Box2D_wrap.cpp Box2D/Box2D.i
#       error: command 'swig' failed: No such file or directory
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for Box2D
#   Running setup.py clean for Box2D
# Failed to build Box2D
# Installing collected packages: Box2D
#   Running setup.py install for Box2D ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for Box2D did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       Using setuptools (version 66.1.1).
#       running install
#       /home/hasitha/jupy/jup_notebook/lib/python3.11/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_py
#       creating build
#       creating build/lib.linux-x86_64-cpython-311
#       creating build/lib.linux-x86_64-cpython-311/Box2D
#       copying library/Box2D/Box2D.py -> build/lib.linux-x86_64-cpython-311/Box2D
#       copying library/Box2D/__init__.py -> build/lib.linux-x86_64-cpython-311/Box2D
#       creating build/lib.linux-x86_64-cpython-311/Box2D/b2
#       copying library/Box2D/b2/__init__.py -> build/lib.linux-x86_64-cpython-311/Box2D/b2
#       running build_ext
#       building 'Box2D._Box2D' extension
#       swigging Box2D/Box2D.i to Box2D/Box2D_wrap.cpp
#       swig -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library/Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D/Box2D_wrap.cpp Box2D/Box2D.i
#       error: command 'swig' failed: No such file or directory
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> Box2D
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
import gymnasium as gym
env = gym.make("LunarLander-v2", render_mode="human")
observation, info = env.reset()

for _ in range(1000):
    action = env.action_space.sample()  # agent policy that uses the observation and info
    observation, reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
        observation, info = env.reset()

env.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/jupy/jup_notebook/lib/python3.11/site-packages/gymnasium/envs/box2d/bipedal_walker.py:15
#      14 try:
# ---> 15     import Box2D
#      16     from Box2D.b2 import (
#      17         circleShape,
#      18         contactListener,
#    (...)
#      22         revoluteJointDef,
#      23     )
#
# ModuleNotFoundError: No module named 'Box2D'
#
# The above exception was the direct cause of the following exception:
#
# DependencyNotInstalled                    Traceback (most recent call last)
# Cell In[7], line 2
#       1 import gymnasium as gym
# ----> 2 env = gym.make("LunarLander-v2", render_mode="human")
#       3 observation, info = env.reset()
#       5 for _ in range(1000):
#
# File ~/jupy/jup_notebook/lib/python3.11/site-packages/gymnasium/envs/registration.py:755, in make(id, max_episode_steps, autoreset, apply_api_compatibility, disable_env_checker, **kwargs)
#     752     env_creator = env_spec.entry_point
#     753 else:
#     754     # Assume it's a string
# --> 755     env_creator = load_env_creator(env_spec.entry_point)
#     757 # Determine if to use the rendering
#     758 render_modes: list[str] | None = None
#
# File ~/jupy/jup_notebook/lib/python3.11/site-packages/gymnasium/envs/registration.py:553, in load_env_creator(name)
#     544 """Loads an environment with name of style ``"(import path):(environment name)"`` and returns the environment creation function, normally the environment class type.
#     545
#     546 Args:
#    (...)
#     550     The environment constructor for the given environment name.
#     551 """
#     552 mod_name, attr_name = name.split(":")
# --> 553 mod = importlib.import_module(mod_name)
#     554 fn = getattr(mod, attr_name)
#     555 return fn
#
# File /usr/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1128, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1149, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/jupy/jup_notebook/lib/python3.11/site-packages/gymnasium/envs/box2d/__init__.py:1
# ----> 1 from gymnasium.envs.box2d.bipedal_walker import BipedalWalker, BipedalWalkerHardcore
#       2 from gymnasium.envs.box2d.car_racing import CarRacing
#       3 from gymnasium.envs.box2d.lunar_lander import LunarLander, LunarLanderContinuous
#
# File ~/jupy/jup_notebook/lib/python3.11/site-packages/gymnasium/envs/box2d/bipedal_walker.py:25
#      16     from Box2D.b2 import (
#      17         circleShape,
#      18         contactListener,
#    (...)
#      22         revoluteJointDef,
#      23     )
#      24 except ImportError as e:
# ---> 25     raise DependencyNotInstalled(
#      26         "Box2D is not installed, run `pip install gymnasium[box2d]`"
#      27     ) from e
#      30 if TYPE_CHECKING:
#      31     import pygame
#
# DependencyNotInstalled: Box2D is not installed, run `pip install gymnasium[box2d]`

# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
env = gym.make("CartPole-v1")

# %%
# !pip3 install pyglet==1.5.27
# Out:
# Requirement already satisfied: pyglet==1.5.27 in ./jup_notebook/lib/python3.11/site-packages (1.5.27)

# %%
env = gym.make("CartPole-v1")
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 score:14.0
# Episode:2 score:18.0
# Episode:3 score:13.0
# Episode:4 score:22.0
# Episode:5 score:10.0

# %%
import gym

from stable_baselines3 import A2C

env = gym.make("CartPole-v1")

model = A2C("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10_000)

obs = env.reset()
for i in range(100):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    env.render()
    if done:
      obs = env.reset()
env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 35.5     |
# |    ep_rew_mean        | 35.5     |
# | time/                 |          |
# |    fps                | 1427     |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.688   |
# |    explained_variance | -0.227   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 1.68     |
# |    value_loss         | 9.98     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 41.7     |
# |    ep_rew_mean        | 41.7     |
# | time/                 |          |
# |    fps                | 1506     |
# |    iterations         | 200      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.616   |
# |    explained_variance | 0.0345   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.83     |
# |    value_loss         | 6.91     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.2     |
# |    ep_rew_mean        | 44.2     |
# | time/                 |          |
# |    fps                | 1533     |
# |    iterations         | 300      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.575   |
# |    explained_variance | 0.0477   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 1.08     |
# |    value_loss         | 5.78     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 49       |
# |    ep_rew_mean        | 49       |
# | time/                 |          |
# |    fps                | 1519     |
# |    iterations         | 400      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.553   |
# |    explained_variance | 0.00791  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.897    |
# |    value_loss         | 5.61     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 54.9     |
# |    ep_rew_mean        | 54.9     |
# | time/                 |          |
# |    fps                | 1494     |
# |    iterations         | 500      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.502   |
# |    explained_variance | -0.016   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 1.44     |
# |    value_loss         | 5.02     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 58.9     |
# |    ep_rew_mean        | 58.9     |
# | time/                 |          |
# |    fps                | 1487     |
# |    iterations         | 600      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.517   |
# |    explained_variance | 0.0158   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 1.85     |
# |    value_loss         | 4.31     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 66.4     |
# |    ep_rew_mean        | 66.4     |
# | time/                 |          |
# |    fps                | 1499     |
# |    iterations         | 700      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.64    |
# |    explained_variance | 0.000484 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.863    |
# |    value_loss         | 3.8      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 68.5     |
# |    ep_rew_mean        | 68.5     |
# | time/                 |          |
# |    fps                | 1503     |
# |    iterations         | 800      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.6     |
# |    explained_variance | 0.000868 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 1.23     |
# |    value_loss         | 3.32     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 70.3     |
# |    ep_rew_mean        | 70.3     |
# | time/                 |          |
# |    fps                | 1513     |
# |    iterations         | 900      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.629   |
# |    explained_variance | 0.0029   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.623    |
# |    value_loss         | 2.82     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 72.4      |
# |    ep_rew_mean        | 72.4      |
# | time/                 |           |
# |    fps                | 1518      |
# |    iterations         | 1000      |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -0.493    |
# |    explained_variance | -6.29e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 0.99      |
# |    value_loss         | 2.4       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 76.2     |
# |    ep_rew_mean        | 76.2     |
# | time/                 |          |
# |    fps                | 1525     |
# |    iterations         | 1100     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.651   |
# |    explained_variance | 2e-05    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.696    |
# |    value_loss         | 1.99     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 78.3     |
# |    ep_rew_mean        | 78.3     |
# | time/                 |          |
# |    fps                | 1530     |
# |    iterations         | 1200     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.432   |
# |    explained_variance | 4.59e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 1.03     |
# |    value_loss         | 1.63     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 77.8     |
# |    ep_rew_mean        | 77.8     |
# | time/                 |          |
# |    fps                | 1535     |
# |    iterations         | 1300     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.34    |
# |    explained_variance | -0.00458 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.913    |
# |    value_loss         | 1.31     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 81.6     |
# |    ep_rew_mean        | 81.6     |
# | time/                 |          |
# |    fps                | 1538     |
# |    iterations         | 1400     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.533   |
# |    explained_variance | 6.68e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.366    |
# |    value_loss         | 1.01     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 84.7      |
# |    ep_rew_mean        | 84.7      |
# | time/                 |           |
# |    fps                | 1537      |
# |    iterations         | 1500      |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.544    |
# |    explained_variance | -2.94e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 0.421     |
# |    value_loss         | 0.749     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 86.8     |
# |    ep_rew_mean        | 86.8     |
# | time/                 |          |
# |    fps                | 1537     |
# |    iterations         | 1600     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.643   |
# |    explained_variance | -2.1e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.289    |
# |    value_loss         | 0.526    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 89.3      |
# |    ep_rew_mean        | 89.3      |
# | time/                 |           |
# |    fps                | 1539      |
# |    iterations         | 1700      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -0.567    |
# |    explained_variance | -8.58e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 0.203     |
# |    value_loss         | 0.345     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 90.4     |
# |    ep_rew_mean        | 90.4     |
# | time/                 |          |
# |    fps                | 1538     |
# |    iterations         | 1800     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.65    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.182    |
# |    value_loss         | 0.203    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93.8     |
# |    ep_rew_mean        | 93.8     |
# | time/                 |          |
# |    fps                | 1541     |
# |    iterations         | 1900     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.52    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.174    |
# |    value_loss         | 0.0946   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 96.4      |
# |    ep_rew_mean        | 96.4      |
# | time/                 |           |
# |    fps                | 1543      |
# |    iterations         | 2000      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.462    |
# |    explained_variance | -3.06e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 0.114     |
# |    value_loss         | 0.0281    |
# -------------------------------------
